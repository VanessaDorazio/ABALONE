# %% [markdown]
# # Analisi Dati ABALONE
# Questa analisi si basa sui dati del 13 settembre 2021 presi a 20 KV e con il led acceso a 3V.
# Mi sono concentrata su come varia lo spettro dell'area in base a come viene definita la baseline e in particolare ho approfondito il caso in cui la baseline viene calcolata come media su 40 campioni poco prima del massimo che consideriamo.

# %% [markdown]
# ## Baseline calcolata come media sui primi 100 campioni

# %% [markdown]
# ## Baseline calcolata come media su 100 campioni poco prima del massimo che considero

# %% [markdown]
# ## Baseline calcolata come media sui primi 40 campioni

# %% [markdown]
# ## Baseline calcolata come media su 40 campioni poco prima del max che considero

# %% [markdown]
# In corrispondenza di area= 45, area=145, area=245 e area=345 possiamo vedere delle strutture quindi plottiamo delle forme d'onda corrispodenti a questi casi per capirne l'andamento.

# %% [markdown]
# * struttura corrispondente a area~45

# %%
# Out:
# Areap40= 40.44999999999163
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# * caso con area~145

# %%
# Out:
# Areap40= 149.49999999998545
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# * caso con area~245

# %%
# Out:
# Areap40= 229.0
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# * caso con area~345

# %%
# Out:
# Areap40= 337.0999999999858
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# * caso con 1000<area<2000

# %%
# Out:
# Areap40= 1657.199999999957
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# * caso area~8000 <br>
#     questi sono i picchi che consideriamo segnale del led e che ci interessano maggiormente

# %%
# Out:
# Areap40= 7704.049999999952
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# # Grafico in scala lineare

# %%
# Out:
# <img src="data:image/png;base64,..." width="1200">
